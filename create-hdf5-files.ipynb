# %%
from torch_snippets import rand, makedir

makedir('data')
FILE_NAME_PREFIX = 'small'

for i in range(1):
    # !python main.py {FILE_NAME_PREFIX}_{rand()} -ve 50 -wa 300 -v -nego 1
# Out:
# HDF5 File opened
# Successfully connected to CARLA
# Starting to record data...
# Destroying 0 NPC vehicles
# Destroying 0 NPC walkers
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ERROR: Spawn failed because of collision at spawn position
# ...
